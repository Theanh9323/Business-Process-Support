# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()

# %%
raw_data = pd.read_csv('EL_products.csv')
raw_data2 = pd.read_csv('EL_order.csv')
raw_data3 = pd.read_csv('EL_best-seller.csv')
raw_data.head()
# Out:
#    product_id         product_name product_brand  product_price  \
# 0           1       Apple iPhone 6        iPhone          87.95
# 1           2        Playstation 4  Game Console         165.99
# 2           3              Macbook       Desktop          12.99
# 3           4       Apple iPhone 7        iPhone          80.99
# 4           5  Google Nexus Player   Set Top Box          11.95
#
#    product_quantity
# 0               102
# 1                17
# 2               140
# 3               178
# 4               144

# %%
df = raw_data.merge(raw_data2, left_on='product_id', right_on='product_id')

# %%
df.head()
# Out:
#    product_id         product_name product_brand  product_price  \
# 0           1       Apple iPhone 6        iPhone          87.95
# 1           2        Playstation 4  Game Console         165.99
# 2           2        Playstation 4  Game Console         165.99
# 3           3              Macbook       Desktop          12.99
# 4           5  Google Nexus Player   Set Top Box          11.95
#
#    product_quantity  order_id  customer_id                     order_date  \
# 0               102      1000          485  2019-05-11T11:55:50.528+07:00
# 1                17       407           32  2013-08-13T13:55:22.040+07:00
# 2                17       941          905  2012-04-04T00:10:32.856+07:00
# 3               140       932          238  2017-08-07T21:48:18.404+07:00
# 4               144       142          348  2010-05-14T22:28:30.859+07:00
#
#    quantity  TotalAmount      status    payment_method
# 0        81     26137.22     shipped            PayPal
# 1       389     27231.92  processing            PayPal
# 2       112     23471.85   delivered  cash on delivery
# 3       130     21955.69   delivered            PayPal
# 4        69     18220.96   delivered  cash on delivery

# %%
df.tail()
# Out:
#      product_id       product_name product_brand  product_price  \
# 995         993  Amazon 4K Fire TV   Set Top Box          167.0
# 996         994         Roku Ultra   Set Top Box           77.0
# 997         995       Nintendo 3DS  Game Console           44.0
# 998         995       Nintendo 3DS  Game Console           44.0
# 999        1000    Amazon Kindle 3      E Reader           91.0
#
#      product_quantity  order_id  customer_id                     order_date  \
# 995               245       776          830  2016-03-26T14:06:19.689+07:00
# 996               117       538          300  2010-08-19T19:41:11.679+07:00
# 997               250       756          431  2013-07-12T21:03:58.504+07:00
# 998               250       953          942  2013-01-07T03:47:20.362+07:00
# 999                57       883          704  2012-06-23T15:15:22.743+07:00
#
#      quantity  TotalAmount      status    payment_method
# 995       293     42826.60  processing            PayPal
# 996       308     20222.08   delivered       credit card
# 997       216     45731.62     shipped  cash on delivery
# 998        79     35379.80  processing       credit card
# 999       160     19871.62     shipped       credit card

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_id        1000 non-null   int64
#  1   product_name      1000 non-null   object
#  2   product_brand     1000 non-null   object
#  3   product_price     1000 non-null   float64
#  4   product_quantity  1000 non-null   int64
#  5   order_id          1000 non-null   int64
#  6   customer_id       1000 non-null   int64
#  7   order_date        1000 non-null   object
#  8   quantity          1000 non-null   int64
#  9   TotalAmount       1000 non-null   float64
#  10  status            1000 non-null   object
#  11  payment_method    1000 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 93.9+ KB

# %%
#drop columns
df.drop(['customer_id'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_id        1000 non-null   int64
#  1   product_name      1000 non-null   object
#  2   product_brand     1000 non-null   object
#  3   product_price     1000 non-null   float64
#  4   product_quantity  1000 non-null   int64
#  5   order_id          1000 non-null   int64
#  6   order_date        1000 non-null   object
#  7   quantity          1000 non-null   int64
#  8   TotalAmount       1000 non-null   float64
#  9   status            1000 non-null   object
#  10  payment_method    1000 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 86.1+ KB

# %%
#checking null value
pd.isnull(df)
# Out:
#      product_id  product_name  product_brand  product_price  product_quantity  \
# 0         False         False          False          False             False
# 1         False         False          False          False             False
# 2         False         False          False          False             False
# 3         False         False          False          False             False
# 4         False         False          False          False             False
# ..          ...           ...            ...            ...               ...
# 995       False         False          False          False             False
# 996       False         False          False          False             False
# 997       False         False          False          False             False
# 998       False         False          False          False             False
# 999       False         False          False          False             False
#
#      order_id  order_date  quantity  TotalAmount  status  payment_method
# 0       False       False     False        False   False           False
# 1       False       False     False        False   False           False
# 2       False       False     False        False   False           False
# 3       False       False     False        False   False           False
# 4       False       False     False        False   False           False
# ..        ...         ...       ...          ...     ...             ...
# 995     False       False     False        False   False           False
# 996     False       False     False        False   False           False
# 997     False       False     False        False   False           False
# 998     False       False     False        False   False           False
# 999     False       False     False        False   False           False
#
# [1000 rows x 11 columns]

# %%
#checking sum of null value 
pd.isnull(df).sum()
# Out:
# product_id          0
# product_name        0
# product_brand       0
# product_price       0
# product_quantity    0
# order_id            0
# order_date          0
# quantity            0
# TotalAmount         0
# status              0
# payment_method      0
# dtype: int64

# %%
#drop null values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'product_brand', 'product_price',
#        'product_quantity', 'order_id', 'order_date', 'quantity', 'TotalAmount',
#        'status', 'payment_method'],
#       dtype='object')

# %%
df.describe()
# Out:
#         product_id  product_price  product_quantity     order_id     quantity  \
# count  1000.000000    1000.000000       1000.000000  1000.000000  1000.000000
# mean    496.250000     107.143220        126.538000   500.500000   199.404000
# std     288.136322      54.200463         74.993977   288.819436   111.721746
# min       1.000000      10.000000          0.000000     1.000000     2.000000
# 25%     240.500000      60.950000         65.000000   250.750000   104.750000
# 50%     501.500000     105.990000        126.500000   500.500000   196.500000
# 75%     746.250000     153.000000        188.000000   750.250000   291.250000
# max    1000.000000     199.000000        256.000000  1000.000000   400.000000
#
#         TotalAmount
# count   1000.000000
# mean   30176.205720
# std    11718.644323
# min    10074.630000
# 25%    19725.747500
# 50%    30582.450000
# 75%    40316.832500
# max    49903.200000

# %%
df.describe(include='all')
# Out:
#          product_id       product_name   product_brand  product_price  \
# count   1000.000000               1000            1000    1000.000000
# unique          NaN                 47               7            NaN
# top             NaN  Amazon 4K Fire TV  Android Mobile            NaN
# freq            NaN                 38             222            NaN
# mean     496.250000                NaN             NaN     107.143220
# std      288.136322                NaN             NaN      54.200463
# min        1.000000                NaN             NaN      10.000000
# 25%      240.500000                NaN             NaN      60.950000
# 50%      501.500000                NaN             NaN     105.990000
# 75%      746.250000                NaN             NaN     153.000000
# max     1000.000000                NaN             NaN     199.000000
#
#         product_quantity     order_id                     order_date  \
# count        1000.000000  1000.000000                           1000
# unique               NaN          NaN                           1000
# top                  NaN          NaN  2019-05-11T11:55:50.528+07:00
# freq                 NaN          NaN                              1
# mean          126.538000   500.500000                            NaN
# std            74.993977   288.819436                            NaN
# min             0.000000     1.000000                            NaN
# 25%            65.000000   250.750000                            NaN
# 50%           126.500000   500.500000                            NaN
# 75%           188.000000   750.250000                            NaN
# max           256.000000  1000.000000                            NaN
#
#            quantity   TotalAmount   status    payment_method
# count   1000.000000   1000.000000     1000              1000
# unique          NaN           NaN        4                 3
# top             NaN           NaN  shipped  cash on delivery
# freq            NaN           NaN      267               344
# mean     199.404000  30176.205720      NaN               NaN
# std      111.721746  11718.644323      NaN               NaN
# min        2.000000  10074.630000      NaN               NaN
# 25%      104.750000  19725.747500      NaN               NaN
# 50%      196.500000  30582.450000      NaN               NaN
# 75%      291.250000  40316.832500      NaN               NaN
# max      400.000000  49903.200000      NaN               NaN
